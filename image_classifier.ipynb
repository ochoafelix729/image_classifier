# %%
import torch
import torchvision
import torch.nn as nn
from torchvision import transforms
from PIL import Image
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# ### Define Input Transformation

# %%
MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
IMAGE_SIZE = 224
image_transforms = transforms.Compose([
                           transforms.Resize(IMAGE_SIZE),
                           transforms.CenterCrop(IMAGE_SIZE),
                           transforms.ToTensor(),
                           transforms.Normalize(mean = MEAN, std = STD)])

index2name = pickle.load(open("imagenet_class_names.pkl", "rb"))

# %% [markdown]
# ### Define Model

# %%
model = torchvision.models.resnet50(pretrained=True)
softmax_layer = nn.Softmax(dim=1)
model.eval()

# %% [markdown]
# ### Classify and Visualize Image

# %%
image_path = "dog.jpg"
original_image = Image.open(image_path).convert("RGB")
image = image_transforms(original_image)
image = image.unsqueeze(0)
output = softmax_layer(model(image))

prediction = torch.argmax(output, dim=1).item()
prob = output[0, prediction].item() * 100
predicted_name = index2name[prediction]

plt.imshow(original_image)
plt.title("Class: %s. Probabilty: %.2f" % (predicted_name, prob) + "%")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Resnet-50

# %%
softmax_layer = nn.Softmax(dim=1)
K = 5

MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
IMAGE_SIZE = 224
image_transforms = transforms.Compose([
  transforms.Resize(IMAGE_SIZE),
  transforms.CenterCrop(IMAGE_SIZE),
  transforms.ToTensor(),
  transforms.Normalize(mean = MEAN, std = STD)])

index2name = pickle.load(open("imagenet_class_names.pkl", "rb"))

images = [
    'image1.jpeg',
    'image2.jpeg',
    'image3.jpeg',
    'image4.jpeg',
    'image5.jpeg',
    'image6.jpeg',
    'image7.jpeg',
    'image8.jpeg',
    'image9.jpeg',
    'image10.jpeg'
]

for image_path in images:
  original_image = Image.open(image_path).convert("RGB")
  image = image_transforms(original_image)
  image = image.unsqueeze(0)
  output = softmax_layer(model(image))

  # top-k prediction
  topk_probs, topk_indices = torch.topk(output, K)
  topk_probs = topk_probs.cpu().detach().numpy()[0]
  topk_indices = topk_indices.cpu().detach().numpy()[0]
  topk_classnames = [index2name[i] for i in topk_indices]

  # output results
  prediction = torch.argmax(output, dim=1).item()
  prob = output[0, prediction].item() * 100
  predicted_name = index2name[prediction]

  lines = [
      f"{j+1}: {name} (Probability: {p*100:.2f}%)"
      for j, (name, p) in enumerate(zip(topk_classnames, topk_probs))
  ]

  plt.imshow(original_image)
  plt.title("\n".join(lines))
  plt.axis("off")
  plt.show()

# %% [markdown]
# ### Resnet-101

# %%
model = torchvision.models.resnet101(pretrained=True)
softmax_layer = nn.Softmax(dim=1)
model.eval()

K = 5

MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
IMAGE_SIZE = 224
image_transforms = transforms.Compose([
  transforms.Resize(IMAGE_SIZE),
  transforms.CenterCrop(IMAGE_SIZE),
  transforms.ToTensor(),
  transforms.Normalize(mean = MEAN, std = STD)])

index2name = pickle.load(open("imagenet_class_names.pkl", "rb"))

images = [
    'image1.jpeg',
    'image2.jpeg',
    'image3.jpeg',
    'image4.jpeg',
    'image5.jpeg',
    'image6.jpeg',
    'image7.jpeg',
    'image8.jpeg',
    'image9.jpeg',
    'image10.jpeg'
]

for image_path in images:
  original_image = Image.open(image_path).convert("RGB")
  image = image_transforms(original_image)
  image = image.unsqueeze(0)
  output = softmax_layer(model(image))

  # top-k prediction
  topk_probs, topk_indices = torch.topk(output, K)
  topk_probs = topk_probs.cpu().detach().numpy()[0]
  topk_indices = topk_indices.cpu().detach().numpy()[0]
  topk_classnames = [index2name[i] for i in topk_indices]

  # output results
  prediction = torch.argmax(output, dim=1).item()
  prob = output[0, prediction].item() * 100
  predicted_name = index2name[prediction]

  lines = [
      f"{j+1}: {name} (Probability: {p*100:.2f}%)"
      for j, (name, p) in enumerate(zip(topk_classnames, topk_probs))
  ]

  plt.imshow(original_image)
  plt.title("\n".join(lines))
  plt.axis("off")
  plt.show()

# %% [markdown]
# ### Densenet-121

# %%
model = torchvision.models.densenet121(pretrained=True)
softmax_layer = nn.Softmax(dim=1)
model.eval()

K = 5

MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
IMAGE_SIZE = 224
image_transforms = transforms.Compose([
  transforms.Resize(IMAGE_SIZE),
  transforms.CenterCrop(IMAGE_SIZE),
  transforms.ToTensor(),
  transforms.Normalize(mean = MEAN, std = STD)])

index2name = pickle.load(open("imagenet_class_names.pkl", "rb"))

images = [
    'image1.jpeg',
    'image2.jpeg',
    'image3.jpeg',
    'image4.jpeg',
    'image5.jpeg',
    'image6.jpeg',
    'image7.jpeg',
    'image8.jpeg',
    'image9.jpeg',
    'image10.jpeg'
]

for image_path in images:
  original_image = Image.open(image_path).convert("RGB")
  image = image_transforms(original_image)
  image = image.unsqueeze(0)
  output = softmax_layer(model(image))

  # top-k prediction
  topk_probs, topk_indices = torch.topk(output, K)
  topk_probs = topk_probs.cpu().detach().numpy()[0]
  topk_indices = topk_indices.cpu().detach().numpy()[0]
  topk_classnames = [index2name[i] for i in topk_indices]

  # output results
  prediction = torch.argmax(output, dim=1).item()
  prob = output[0, prediction].item() * 100
  predicted_name = index2name[prediction]

  lines = [
      f"{j+1}: {name} (Probability: {p*100:.2f}%)"
      for j, (name, p) in enumerate(zip(topk_classnames, topk_probs))
  ]

  plt.imshow(original_image)
  plt.title("\n".join(lines))
  plt.axis("off")
  plt.show()

# %% [markdown]
# ### Define Training Data Loader

# %%
train_batch_size = 32
train_dataset =  torchvision.datasets.CIFAR10(
    root = "data/",
    transform = torchvision.transforms.ToTensor(),
    train = True,
    download = True
)
train_loader = torch.utils.data.DataLoader(
    dataset = train_dataset,
    batch_size = train_batch_size,
    shuffle = True
)
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 30.1MB/s]

# %% [markdown]
# ### Define Model and Training Framework

# %%
class ClassificationModel(torch.nn.Module):
    def __init__ (self):
        super(ClassificationModel, self).__init__()
        self.num_classes = 10
        self.linear1 = nn.Linear(3 * 32 * 32, 512)
        self.relu1 = nn.ReLU()
        self.linear2 = nn.Linear(512, 256)
        self.relu2 = nn.ReLU()
        self.linear3 = nn.Linear(256, self.num_classes)

    def forward(self, x):
        n,c,h,w = x.size()
        x = x.reshape(n,-1)
        x = self.relu1(self.linear1(x))
        x = self.relu2(self.linear2(x))
        x = self.linear3(x)
        return x

# %%
train_batch_size = 32

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, num_workers=2)

cuda = torch.cuda.is_available()
model = ClassificationModel()
if cuda:
  model.cuda()

model.train()
learning_rate = 0.001
num_epochs = 3
optim = torch.optim.Adam(model.parameters(), lr = learning_rate)
loss_fn = nn.CrossEntropyLoss()
loss_logger = []
accuracy_logger = []

for epoch in range(1, num_epochs + 1):
  for it, (images, labels) in enumerate(train_loader):
      if cuda:
        images = images.cuda()
        labels = labels.cuda()

      # forward pass
      outputs = model(images)
      loss = loss_fn(outputs, labels)

      # compute accuracy
      _, predicted = torch.max(outputs.data, 1)
      total = labels.size(0)
      correct = (predicted == labels).sum().item()
      accuracy = correct / total

      optim.zero_grad()
      loss.backward()
      optim.step()

      loss_logger.append(loss.item())
      accuracy_logger.append(accuracy)

      if it % 200 == 0:
        print("Epoch [%d/%d]. Iter [%d/%d]. Loss: %0.4f. Accuracy: %.2f" % (epoch, num_epochs, it + 1, len(train_loader), loss, accuracy))

torch.save(model.state_dict(), "CIFAR10-Model.pth")

# Write your code to visualize the training losses over interations
plt.plot(loss_logger)
plt.title("Training Loss over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# Write your code to visualize the training accuracies over interations
plt.plot(accuracy_logger)
plt.title("Training Accuracy over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.show()
# Out:
# Epoch [1/3]. Iter [1/1563]. Loss: 2.3040. Accuracy: 0.09
# Epoch [1/3]. Iter [201/1563]. Loss: 1.5704. Accuracy: 0.44
# Epoch [1/3]. Iter [401/1563]. Loss: 1.8651. Accuracy: 0.28
# Epoch [1/3]. Iter [601/1563]. Loss: 1.5409. Accuracy: 0.53
# Epoch [1/3]. Iter [801/1563]. Loss: 1.3367. Accuracy: 0.47
# Epoch [1/3]. Iter [1001/1563]. Loss: 1.9334. Accuracy: 0.25
# Epoch [1/3]. Iter [1201/1563]. Loss: 1.6209. Accuracy: 0.38
# Epoch [1/3]. Iter [1401/1563]. Loss: 1.9486. Accuracy: 0.28
# Epoch [2/3]. Iter [1/1563]. Loss: 1.9081. Accuracy: 0.44
# Epoch [2/3]. Iter [201/1563]. Loss: 1.4477. Accuracy: 0.41
# Epoch [2/3]. Iter [401/1563]. Loss: 1.7795. Accuracy: 0.41
# Epoch [2/3]. Iter [601/1563]. Loss: 1.3420. Accuracy: 0.56
# Epoch [2/3]. Iter [801/1563]. Loss: 1.5103. Accuracy: 0.50
# Epoch [2/3]. Iter [1001/1563]. Loss: 1.7784. Accuracy: 0.38
# Epoch [2/3]. Iter [1201/1563]. Loss: 1.4621. Accuracy: 0.38
# Epoch [2/3]. Iter [1401/1563]. Loss: 1.5934. Accuracy: 0.41
# ...

# %% [markdown]
# ### Load Model and Evaluate Model On Testing Dataset

# %%
cuda = torch.cuda.is_available()
model = ClassificationModel()
if cuda:
  model.cuda()

# Load your trained model in the previous step
model.load_state_dict(torch.load("CIFAR10-Model.pth"))
model.eval()

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

final_accuracy = 0.0
final_top_5_accuracy = 0.0
all_preds = []
all_labels = []

for it, (images, labels) in enumerate(test_loader):
  if cuda:
    images = images.cuda()
    labels = labels.cuda()

  outputs = model(images)
  _, predicted = outputs.max(1)
  correct = (predicted == labels).sum().item()
  accuracy = correct / labels.size(0)

  # top-5 Accuracy
  top5 = torch.topk(outputs, 5, dim=1).indices
  top5_correct = torch.eq(top5, labels.unsqueeze(1)).sum().item()
  top_5_accuracy = top5_correct / labels.size(0)

  if accuracy == 1:
    images = images.cpu().detach().numpy()[0]
    outputs = outputs.cpu().detach().numpy()[0]
    labels = labels.cpu().detach().numpy()[0]

  final_accuracy += accuracy
  final_top_5_accuracy += top_5_accuracy

  all_preds.extend(predicted.cpu().numpy())
  all_labels.extend(labels.cpu().numpy())

  if it % 500 == 0:
    print("Iter [%d/%d]. Accuracy: %.2f" % (it + 1, len(test_loader), accuracy))

print("Final Accuracy: %0.2f" % (final_accuracy / len(test_loader)))
print("Top 5 Accuracy: %0.3f" % (top_5_accuracy / len(test_loader)))

from sklearn.metrics import confusion_matrix
import seaborn as sns

# confusion matrix visualization
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_dataset.classes,
            yticklabels=test_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

import random

# correct predictions visualizations
correct_samples = []
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        if cuda:
            images = images.cuda()
            labels = labels.cuda()
        outputs = model(images)
        _, preds = outputs.max(1)
        for img, pred, label in zip(images, preds, labels):
            if pred == label:
                correct_samples.append((img.cpu(), pred.cpu(), label.cpu()))
            if len(correct_samples) >= 10:
                break
        if len(correct_samples) >= 10:
            break

class_names = test_dataset.classes
plt.figure(figsize=(12, 6))
for i, (img, pred, label) in enumerate(correct_samples):
    img = img.permute(1, 2, 0) * 0.5 + 0.5  # unnormalize
    plt.subplot(2, 5, i+1)
    plt.imshow(img.numpy())
    plt.title(f"Pred: {class_names[pred]}\nLabel: {class_names[label]}")
    plt.axis('off')
plt.suptitle("10 Correctly Predicted CIFAR-10 Samples")
plt.show()
# Out:
# Iter [1/313]. Accuracy: 0.56
# Final Accuracy: 0.50
# Top 5 Accuracy: 0.003
